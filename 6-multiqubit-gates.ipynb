# %% [markdown]
# ### CNOT Gate

# %%
from qiskit import *
from qiskit.tools.visualization import plot_bloch_multivector
from math import pi
# %matplotlib inline

# %%
circuit = QuantumCircuit(3)

circuit.x(0)
circuit.cnot(0, 1)
# cx is the same as cnot
circuit.cx(1, 2)

circuit.draw(output='mpl')
# Out:
# /var/folders/8s/0mgsdm81367b1mr6dd9yxj6m0000gn/T/ipykernel_37503/3753133216.py:4: DeprecationWarning: The method ``qiskit.circuit.quantumcircuit.QuantumCircuit.cnot()`` is deprecated as of qiskit 0.45.0. It will be removed in the Qiskit 1.0.0 release. Use QuantumCircuit.cx as direct replacement.
#   circuit.cnot(0, 1)
# /Users/uladkaminski/Projects/qc/quantum-computing-foundation/.venv/lib/python3.12/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
backend = Aer.get_backend("statevector_simulator")
statevector = execute(circuit, backend=backend).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# ### CCNOT Gate (Toffoli gate)

# %%
circuit = QuantumCircuit(3)
circuit.y([0, 1])
circuit.rx(pi/3, 2)
# circuit.ccx(0,1,2)
# or
# circuit.toffoli(0,1,2)

circuit.draw(output='mpl')

# %%
backend = Aer.get_backend("statevector_simulator")
statevector = execute(circuit, backend=backend).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# ### Swap and Fredkin (CSWAP) Gates

# %%
circuit = QuantumCircuit(3)

circuit.h(1)
circuit.rx(-pi/4, 2)

# circuit.swap(1,2)

circuit.x(0)
circuit.fredkin(0, 1, 2)
# or cswap(0, 1, 2)

circuit.draw(output='mpl')

# %%
backend = Aer.get_backend("statevector_simulator")
statevector = execute(circuit, backend=backend).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# ### Challenge
#
# Represent logic XOR and AND operation.

# %%
circuit = QuantumCircuit(4, 2)

circuit.x(1)
circuit.x(0)
circuit.barrier()

circuit.cx(0, 2)
circuit.cx(1, 2)
circuit.ccx(0, 1, 3)

circuit.barrier()
circuit.measure(2, 0)  # measure XOR
circuit.measure(3, 1)  # measure AND

circuit.draw(output='mpl')
